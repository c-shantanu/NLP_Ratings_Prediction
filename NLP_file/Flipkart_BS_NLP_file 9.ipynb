# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # Flipkart.com

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'class' : '_27M-vq'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('div',{'class':'t-ZTKy'}).text.strip(),
            'rating': float(item.find('div',{'class':'_3LWZlK'}).text.strip())
            }
            review_list.append(review)
            
    except:
        pass

# %%
for i in range(1,1200):
    soup = get_soup(f'https://www.flipkart.com/eveready-10-w-standard-b22-led-bulb/product-reviews/itmb1e8f9da0659c?pid=BLBF59BG7ZUQ6GN8&lid=LSTBLBF59BG7ZUQ6GN8KUCVLL&marketplace=FLIPKART&page={i}')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
# Out:
# Getting Page: 1
# 10
# Getting Page: 2
# 20
# Getting Page: 3
# 30
# Getting Page: 4
# 40
# Getting Page: 5
# 50
# Getting Page: 6
# 60
# Getting Page: 7
# 70
# Getting Page: 8
# 80
# Getting Page: 9
# 90
# Getting Page: 10
# 100
# Getting Page: 11
# 110
# Getting Page: 12
# 120
# Getting Page: 13
# 130
# Getting Page: 14
# 140
# Getting Page: 15
# 150
# Getting Page: 16
# 160
# Getting Page: 17
# 170
# Getting Page: 18
# 180
# Getting Page: 19
# 190
# Getting Page: 20
# 200
# Getting Page: 21
# 210
# Getting Page: 22
# 220
# Getting Page: 23
# 230
# Getting Page: 24
# 240
# Getting Page: 25
# 250
# Getting Page: 26
# 260
# Getting Page: 27
# 270
# Getting Page: 28
# 280
# Getting Page: 29
# 290
# Getting Page: 30
# 300
# Getting Page: 31
# 310
# Getting Page: 32
# 320
# Getting Page: 33
# 330
# Getting Page: 34
# 340
# Getting Page: 35
# 350
# Getting Page: 36
# 360
# Getting Page: 37
# 370
# Getting Page: 38
# 380
# Getting Page: 39
# 390
# Getting Page: 40
# 400
# ...

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_flip_9.csv', index=False)
print('END')
# Out:
# END

# %%
pd.set_option('max.rows',10000)
df
# Out:
#                                                  review  rating
# 0     nice packaging and time to time delivery flipk...     5.0
# 1     Excellent product in these aspects1-Energy Sav...     5.0
# 2     I used eveready 10W led bulb for last 4-5 year...     5.0
# 3     As these bulbs are of 10w and provide almost s...     5.0
# 4     One of the best products and also best deals I...     5.0
# 5     LED 10w bulb is giving very good brightness. W...     5.0
# 6     its BEE star rating is 2/5 as compared to phil...     2.0
# 7     I am using Eveready LED for last 5-6 year. Thi...     1.0
# 8     Good product, good luminance, good energy savi...     4.0
# 9     lighting is energitic blueWorks fine Excellent...     5.0
# 10    Amazing LED bulb, bought it for our village Te...     5.0
# 11    Product is really good, sufficient light for m...     5.0
# 12    I got 10pices LED bulb 9w as shown in picture,...     5.0
# 13    It's 2nd time I'm buying Eveready led bulbs.Im...     4.0
# ...

# %%
df.shape
# Out:
# (9958, 2)
