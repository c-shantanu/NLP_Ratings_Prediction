# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # amazon.in

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'data-hook' : 'review'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('span',{'data-hook':'review-body'}).text.strip(),
            'rating': float(item.find('i',{'data-hook':'review-star-rating'}).text.replace('out of 5 stars',"").strip())
            }
            review_list.append(review)
    except:
        pass

# %%
for i in range(1,1199):
    soup = get_soup(f'https://www.amazon.in/product-reviews/B08Z98BTDR/ref=cm_cr_getr_d_paging_btm_next_2?ie=UTF8&refRID=19TYBE3RHEK1EMFS2YZP&filterByStar=two_star&pageNumber={i}')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class':'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# Getting Page: 1
# 0
# Getting Page: 2
# 10
# Getting Page: 3
# 10
# Getting Page: 4
# 10
# Getting Page: 5
# 20
# Getting Page: 6
# 20
# Getting Page: 7
# 20
# Getting Page: 8
# 20
# Getting Page: 9
# 20
# Getting Page: 10
# 30
# Getting Page: 11
# 30
# Getting Page: 12
# 30
# Getting Page: 13
# 30
# Getting Page: 14
# 30
# Getting Page: 15
# 30
# Getting Page: 16
# 40
# Getting Page: 17
# 40
# Getting Page: 18
# 40
# Getting Page: 19
# 40
# Getting Page: 20
# 40
# Getting Page: 21
# 40
# Getting Page: 22
# 40
# Getting Page: 23
# 40
# Getting Page: 24
# 40
# Getting Page: 25
# 50
# Getting Page: 26
# 50
# Getting Page: 27
# 50
# Getting Page: 28
# 50
# Getting Page: 29
# 50
# Getting Page: 30
# 50
# Getting Page: 31
# 50
# Getting Page: 32
# 50
# Getting Page: 33
# 50
# Getting Page: 34
# 50
# Getting Page: 35
# 50
# Getting Page: 36
# 60
# Getting Page: 37
# 60
# Getting Page: 38
# 60
# Getting Page: 39
# 60
# Getting Page: 40
# 70
# Getting Page: 41
# 70
# Getting Page: 42
# 70
# ...

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_16.csv', index=False)
print('END')
# Out:
# END

# %%
pd.set_option('max.rows',1000)

# %%
df
# Out:
#                                                 review  rating
# 0    Hi all, kindly note this is for the seller to ...     2.0
# 1    Quite useless... takes a lot of effort to pull...     2.0
# 2    This was my second time to buy this product. W...     2.0
# 3    I am posting this review after using this prod...     2.0
# 4    We purchased this product based on the reviews...     2.0
# 5    I am writing this  review after using it for a...     2.0
# 6    The product seems duplicate as there is just a...     2.0
# 7    It’s a very delicate plastic body which easily...     2.0
# 8    Purchased in Jan 21 and within 3 months the st...     2.0
# 9    1. Simply pull several times to cut food items...     2.0
# 10   Very nice blade like razor blade,I seen as ben...     2.0
# 11   It’s really helpful for chopping veggies but t...     2.0
# 12   I bought this product in january 2019. Initial...     2.0
# 13   This is a great and very handy product, But th...     2.0
# ...
