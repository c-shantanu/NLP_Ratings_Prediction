# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # amazon.in

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'data-hook' : 'review'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('span',{'data-hook':'review-body'}).text.strip(),
            'rating': float(item.find('i',{'data-hook':'review-star-rating'}).text.replace('out of 5 stars',"").strip())
            }
            review_list.append(review)
    except:
        pass

# %%
for i in range(1,1199):
    soup = get_soup(f'https://www.amazon.in/product-reviews/B08HLTFB33/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews&pageNumber={i}#reviews-filter-bar')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class':'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# Getting Page: 1
# 10
# Getting Page: 2
# 10
# Getting Page: 3
# 10
# Getting Page: 4
# 10
# Getting Page: 5
# 10
# Getting Page: 6
# 10
# Getting Page: 7
# 10
# Getting Page: 8
# 10
# Getting Page: 9
# 10
# Getting Page: 10
# 10
# Getting Page: 11
# 10
# Getting Page: 12
# 10
# Getting Page: 13
# 10
# Getting Page: 14
# 20
# Getting Page: 15
# 20
# Getting Page: 16
# 20
# Getting Page: 17
# 20
# Getting Page: 18
# 20
# Getting Page: 19
# 20
# Getting Page: 20
# 30
# Getting Page: 21
# 30
# Getting Page: 22
# 30
# Getting Page: 23
# 30
# Getting Page: 24
# 30
# Getting Page: 25
# 30
# Getting Page: 26
# 30
# Getting Page: 27
# 40
# Getting Page: 28
# 40
# Getting Page: 29
# 50
# Getting Page: 30
# 50
# Getting Page: 31
# 50
# Getting Page: 32
# 50
# Getting Page: 33
# 50
# Getting Page: 34
# 60
# Getting Page: 35
# 70
# Getting Page: 36
# 70
# Getting Page: 37
# 70
# Getting Page: 38
# 70
# Getting Page: 39
# 70
# Getting Page: 40
# 70
# Getting Page: 41
# 70
# Getting Page: 42
# 70
# Getting Page: 43
# 77

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_15.csv', index=False)
print('END')
# Out:
# END

# %%
pd.set_option('max.rows',1000)

# %%
df
# Out:
#                                                review  rating
# 0   Delivered on 9thfeb21,writing review on 11feb2...     2.0
# 1   Used this for my iPhone 7 and no bass at all. ...     2.0
# 2   It lasted for a month, yeah you read that righ...     2.0
# 3   The product was delivered the same day I purch...     2.0
# 4   There is no issue with sound quality or batter...     2.0
# 5   Used it for 2 months after that it began disco...     2.0
# 6   If you are an iphone user like I’m;Music listi...     2.0
# 7   This product is looks good but I don't know th...     2.0
# 8   For media playing activities like watching vid...     2.0
# 9   Sound quality for audio and video files are ve...     2.0
# 10  Doesn't have Quick switch option or button to ...     2.0
# 11  Your browser does not support HTML5 video.\n\n...     2.0
# 12  I first gave 4 stars as it had good sound,  bu...     2.0
# 13  Your browser does not support HTML5 video.\n\n...     2.0
# 14  Aotomatic pair is so delayed 2 to 3 times we s...     2.0
# 15  Not working properly, gets disconnected within...     2.0
# 16  Boat Rockerz 255pro plus better than one plus ...     2.0
# 17  Battery backup is not as expected. I tried to ...     2.0
# 18  Best things=====sound quality+bass+design+blut...     2.0
# 19  Overalp Sound quality is good but the vocals t...     2.0
# 20  I have purchased 10 days ago and now mic is no...     2.0
# 21  Not able to listen with Right ear phone, Only ...     2.0
# 22  It's been 2 months already and right side of e...     2.0
# 23     Need to improveI think my I got damage product     2.0
# 24  Pros - Sound quality good for songs and others...     2.0
# 25  If you have a poco f1 don't buy this.Has some ...     2.0
# 26                               Battery capacity low     2.0
# 27  Left earpiece automatically stopped working. I...     2.0
# 28  Calls and meetings and sometimes songs.. was d...     2.0
# 29  I buy this neckbend for running but after 1 da...     2.0
# 30  Neckband disconnect 5-10sec and connect again ...     2.0
# 31  Everthing is working fine except noise getting...     2.0
# 32  Battery life is short it's less than 10 hoursE...     2.0
# 33  Worst product after using for 4 months it stop...     2.0
# 34  The more sharpen side the name bid bass editio...     2.0
# 35  There is cracking sound while playing music af...     2.0
# 36  My both ears becomes painful. I have no option...     2.0
# 37    1 hours later right side earbuds🎧 not working..     2.0
# 38  Not of good sound quality,not autoconnected in...     2.0
# 39  In game sound is slow and delay voice in my mi...     2.0
# 40  After 20 days, headphones started glitch sound...     2.0
# 41  My headphone not working...how can I return an...     2.0
# 42  Somedays using this product sound quality is n...     2.0
# 43                    Mic stopped working in 5 months     2.0
# 44                           Realmi is suparb base...     2.0
# 45                    Performance is not as expected,     2.0
# 46     Received faulty , can’t change due to lockdown     2.0
# 47  Sound quality is good,but the microphone is no...     2.0
# 48      Not recommended noise cancellation is poor...     2.0
# 49  The sound of one ear bud reduced after a few d...     2.0
# 50  Very bad on nahi horaha 4 mahine mein hi khara...     2.0
# 51                    Not as better as normal edition     2.0
# 52                    Only one sided sound is hearing     2.0
# 53                     Not it is not working properly     2.0
# 54      Quality is good but ,connectivity is very bad     2.0
# 55                      Jitna  suna tha utna acha nhi     2.0
# 56                                       Lagged a lot     2.0
# 57                              It is getting damaged     2.0
# 58                        Right side not coming sound     2.0
# 59                   It is not working after 2 months     2.0
# 60                         Got damaged within a month     2.0
# 61                         Sometimes it's not working     2.0
# 62                      Pathetic, broke after a month     2.0
# 63                          Mic problem in two months     2.0
# 64                          Battery is not up to mark     2.0
# 65                           Nothing that should like     2.0
# 66                                   Bass not so good     2.0
# 67                            Sound quality not good.     2.0
# 68                            Sound quality was good.     2.0
# 69                                    Average quality     2.0
# 70  Google assistant doesn't works at all, sound q...     2.0
# 71  After 6 months this product have many problems...     2.0
# 72  Worst sound quality compared to basic edition ...     2.0
# 73  Very bad experience. Not working after 2 days ...     2.0
# 74  Battery drained early, not price worthy, even ...     2.0
# 75  Poor mic quality...make too much noise while i...     2.0
# 76  Your browser does not support HTML5 video.\n\n...     2.0
