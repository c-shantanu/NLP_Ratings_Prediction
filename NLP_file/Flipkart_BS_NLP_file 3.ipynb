# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # Flipkart.com

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'class' : '_27M-vq'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('div',{'class':'t-ZTKy'}).text.strip(),
            'rating': float(item.find('div',{'class':'_3LWZlK'}).text.strip())
            }
            review_list.append(review)
            
    except:
        pass

# %%
for i in range(1,1200):
    soup = get_soup(f'https://www.flipkart.com/apple-iphone-se-black-64-gb/product-reviews/itm4d3d5718a5c95?pid=MOBFWQ6BR3MK7AUG&lid=LSTMOBFWQ6BR3MK7AUGEJNZLF&marketplace=FLIPKART&page={i}')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
# Out:
# Getting Page: 1
# 10
# Getting Page: 2
# 20
# Getting Page: 3
# 30
# Getting Page: 4
# 40
# Getting Page: 5
# 50
# Getting Page: 6
# 60
# Getting Page: 7
# 70
# Getting Page: 8
# 80
# Getting Page: 9
# 90
# Getting Page: 10
# 100
# Getting Page: 11
# 110
# Getting Page: 12
# 120
# Getting Page: 13
# 129
# Getting Page: 14
# 139
# Getting Page: 15
# 149
# Getting Page: 16
# 159
# Getting Page: 17
# 169
# Getting Page: 18
# 179
# Getting Page: 19
# 189
# Getting Page: 20
# 199
# Getting Page: 21
# 209
# Getting Page: 22
# 219
# Getting Page: 23
# 229
# Getting Page: 24
# 239
# Getting Page: 25
# 249
# Getting Page: 26
# 259
# Getting Page: 27
# 269
# Getting Page: 28
# 279
# Getting Page: 29
# 289
# Getting Page: 30
# 299
# Getting Page: 31
# 309
# Getting Page: 32
# 319
# Getting Page: 33
# 329
# Getting Page: 34
# 339
# Getting Page: 35
# 349
# Getting Page: 36
# 359
# Getting Page: 37
# 369
# Getting Page: 38
# 379
# Getting Page: 39
# 389
# Getting Page: 40
# 399
# ...

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_flip_3.csv', index=False)
print('END')
# Out:
# END

# %%
pd.set_option('max.rows',10000)
df
# Out:
#                                                  review  rating
# 0     Great device. Let me tell the Pros..1. Superb ...     5.0
# 1     This iPhone SE is the best phone ever you get....     5.0
# 2     Who all loves older size i.e., 4.7 inch type s...     5.0
# 3     Mobile is very handy. Packed with good perform...     4.0
# 4     This is my second iphone after iphone 4s. I’ve...     5.0
# 5     As always compact and handy ... with good imag...     4.0
# 6     Totally worth the price if:- you are a iOS fan...     4.0
# 7     Camera is best. Mobile performance is good. 4....     4.0
# 8     People talk about it’s battery backup?? man I’...     5.0
# 9     Keep the battery aside and I don’t see any oth...     4.0
# 10    If you are going to use apple for first time t...     4.0
# 11    Let's face it. The main reason you're even con...     4.0
# 12    One word.. beautiful iphone ❤️ premium feelJus...     5.0
# 13    iPhone SE 2020 Looks premium😍 Battery:-Most of...     5.0
# ...
