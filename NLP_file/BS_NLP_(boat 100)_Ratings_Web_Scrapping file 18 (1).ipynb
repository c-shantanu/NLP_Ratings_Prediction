# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # amazon.in

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'data-hook' : 'review'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('span',{'data-hook':'review-body'}).text.strip(),
            'rating': float(item.find('i',{'data-hook':'review-star-rating'}).text.replace('out of 5 stars',"").strip())
            }
            review_list.append(review)
    except:
        pass

# %%
for i in range(1,1199):
    soup = get_soup(f'https://www.amazon.in/product-reviews/B071Z8M4KX/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&filterByStar=two_star&reviewerType=all_reviews&pageNumber={i}#reviews-filter-bar')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class':'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# Getting Page: 1
# 0
# Getting Page: 2
# 10
# Getting Page: 3
# 10
# Getting Page: 4
# 10
# Getting Page: 5
# 20
# Getting Page: 6
# 20
# Getting Page: 7
# 20
# Getting Page: 8
# 30
# Getting Page: 9
# 40
# Getting Page: 10
# 50
# Getting Page: 11
# 50
# Getting Page: 12
# 60
# Getting Page: 13
# 60
# Getting Page: 14
# 60
# Getting Page: 15
# 60
# Getting Page: 16
# 60
# Getting Page: 17
# 60
# Getting Page: 18
# 60
# Getting Page: 19
# 60
# Getting Page: 20
# 60
# Getting Page: 21
# 60
# Getting Page: 22
# 70
# Getting Page: 23
# 70
# Getting Page: 24
# 80
# Getting Page: 25
# 80
# Getting Page: 26
# 90
# Getting Page: 27
# 90
# Getting Page: 28
# 90
# Getting Page: 29
# 90
# Getting Page: 30
# 100
# Getting Page: 31
# 110
# Getting Page: 32
# 120
# Getting Page: 33
# 120
# Getting Page: 34
# 120
# Getting Page: 35
# 120
# Getting Page: 36
# 130
# Getting Page: 37
# 140
# Getting Page: 38
# 140
# Getting Page: 39
# 150
# Getting Page: 40
# 160
# Getting Page: 41
# 160
# ...

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_18.csv', index=False)
print('END')
# Out:
# END

# %%
df
# Out:
#                                                 review  rating
# 0    Material quality is just like any other headph...     2.0
# 1    Your browser does not support HTML5 video.\n\n...     2.0
# 2    Very much dissatisfied of the sound quality of...     2.0
# 3    It is a filmsy product seriously. I mean it mi...     2.0
# 4    The sound quality is average as there is too m...     2.0
# ..                                                 ...     ...
# 865  I Use Many Earphones there Good Bt after that ...     2.0
# 866  Average bass while it's on high volume it's ki...     2.0
# 867  Sound quality is okay.Ya it has 'NO' tangle wi...     2.0
# 868  Although the sound quality is fine but the bas...     2.0
# 869  Sound quality not impressive. Build quality is...     2.0
#
# [870 rows x 2 columns]
