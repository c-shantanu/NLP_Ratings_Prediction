# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # amazon.in

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'data-hook' : 'review'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('span',{'data-hook':'review-body'}).text.strip(),
            'rating': float(item.find('i',{'data-hook':'review-star-rating'}).text.replace('out of 5 stars',"").strip())
            }
            review_list.append(review)
    except:
        pass

# %%
for i in range(1,999):
    soup = get_soup(f'https://www.amazon.in/JBL-Portable-Wireless-Bluetooth-Speaker/product-reviews/B00TFGWAA8/ref=cm_cr_getr_d_paging_btm_next_2?ie=UTF8&reviewerType=avp_only_reviews&pageNumber={i}')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class':'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# Getting Page: 1
# 10
# Getting Page: 2
# 10
# Getting Page: 3
# 10
# Getting Page: 4
# 20
# Getting Page: 5
# 20
# Getting Page: 6
# 20
# Getting Page: 7
# 30
# Getting Page: 8
# 30
# Getting Page: 9
# 30
# Getting Page: 10
# 40
# Getting Page: 11
# 40
# Getting Page: 12
# 40
# Getting Page: 13
# 40
# Getting Page: 14
# 40
# Getting Page: 15
# 40
# Getting Page: 16
# 50
# Getting Page: 17
# 50
# Getting Page: 18
# 50
# Getting Page: 19
# 50
# Getting Page: 20
# 50
# Getting Page: 21
# 50
# Getting Page: 22
# 60
# Getting Page: 23
# 60
# Getting Page: 24
# 60
# Getting Page: 25
# 70
# Getting Page: 26
# 80
# Getting Page: 27
# 80
# Getting Page: 28
# 80
# Getting Page: 29
# 80
# Getting Page: 30
# 80
# Getting Page: 31
# 80
# Getting Page: 32
# 80
# Getting Page: 33
# 80
# Getting Page: 34
# 80
# Getting Page: 35
# 80
# Getting Page: 36
# 80
# Getting Page: 37
# 80
# Getting Page: 38
# 80
# Getting Page: 39
# 80
# Getting Page: 40
# 80
# Getting Page: 41
# 80
# Getting Page: 42
# 80
# ...

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_9.csv', index=False)
print('END')
# Out:
# END

# %%
df
# Out:
#                                                 review  rating
# 0    I bought this after reading many reviews on Am...     3.0
# 1    Average speaker, i bought it for watching movi...     3.0
# 2    I was using JBL go since last one year and it ...     4.0
# 3    Excellent product from JBL, I really loved it....     5.0
# 4    After a detailed research bought this as a gif...     4.0
# ..                                                 ...     ...
# 665  The product was working fine for a month and n...     1.0
# 666                                              Super     5.0
# 667  Nyc Audio Quality but Bass Is Little bit Less ...     4.0
# 668  Good sound quality..light weight... Battery is...     5.0
# 669                                               Good     4.0
#
# [670 rows x 2 columns]
