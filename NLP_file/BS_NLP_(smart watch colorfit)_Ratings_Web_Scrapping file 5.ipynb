# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# # amazon.in

# %%
review_list = []

# %%
def get_soup(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    return soup

# %%
def get_reviews(soup):
    reviews=soup.find_all('div',{'data-hook' : 'review'})
    try:
        for item in reviews:
            review={    
            'review' : item.find('span',{'data-hook':'review-body'}).text.strip(),
            'rating': float(item.find('i',{'data-hook':'review-star-rating'}).text.replace('out of 5 stars',"").strip())
            }
            review_list.append(review)
    except:
        pass

# %%
for i in range(1,999):
    soup = get_soup(f'https://www.amazon.in/Noise-Colorfit-Pro-Touch-Control/product-reviews/B07YY1BY5B/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber={i}')
    print(f'Getting Page: {i}')
    get_reviews(soup)
    print(len(review_list))
    if not soup.find('li', {'class':'a-disabled a-last'}):
        pass
    else:
        break
# Out:
# Getting Page: 1
# 0
# Getting Page: 2
# 0
# Getting Page: 3
# 0
# Getting Page: 4
# 0
# Getting Page: 5
# 0
# Getting Page: 6
# 0
# Getting Page: 7
# 0
# Getting Page: 8
# 0
# Getting Page: 9
# 0
# Getting Page: 10
# 10
# Getting Page: 11
# 10
# Getting Page: 12
# 10
# Getting Page: 13
# 10
# Getting Page: 14
# 10
# Getting Page: 15
# 10
# Getting Page: 16
# 10
# Getting Page: 17
# 10
# Getting Page: 18
# 10
# Getting Page: 19
# 10
# Getting Page: 20
# 10
# Getting Page: 21
# 10
# Getting Page: 22
# 10
# Getting Page: 23
# 10
# Getting Page: 24
# 20
# Getting Page: 25
# 20
# Getting Page: 26
# 20
# Getting Page: 27
# 30
# Getting Page: 28
# 30
# Getting Page: 29
# 40
# Getting Page: 30
# 40
# Getting Page: 31
# 50
# Getting Page: 32
# 50
# Getting Page: 33
# 60
# Getting Page: 34
# 70
# Getting Page: 35
# 70
# Getting Page: 36
# 70
# Getting Page: 37
# 80
# Getting Page: 38
# 80
# Getting Page: 39
# 80
# Getting Page: 40
# 80
# Getting Page: 41
# 80
# Getting Page: 42
# 90
# ...

# %%
df = pd.DataFrame(review_list)
df.to_csv('Ratings_nlp_5.csv', index=False)
print('END')
# Out:
# END

# %%
df
# Out:
#                                                  review  rating
# 0     My first smartwatch. I think it has good value...     4.0
# 1     Well, now that the product is in use since las...     4.0
# 2     The watch OS and the NoiseFit app are utter ga...     1.0
# 3     Like:External build - Comparable to that of IW...     4.0
# 4     Previously i faced connection issue. Tgen i wr...     1.0
# ...                                                 ...     ...
# 1325              Very nice watch and very good service     5.0
# 1326  Awesome watch 👍 nice working and look wise too...     5.0
# 1327  Noise watch is great for the price range that ...     5.0
# 1328  Adapter was not there in the box is there any ...     3.0
# 1329                      Sleep tracking is not working     4.0
#
# [1330 rows x 2 columns]
